# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head(10)
# Out:
#         EIN                                               NAME  \
# 0  10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1  10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2  10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3  10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4  10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5  10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6  10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7  10566033                          ISRAEL EMERGENCY ALLIANCE
# 8  10570430                                   ARAMCO BRATS INC
# 9  10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
#
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN','NAME'],axis=1)

# %%
# Determine the number of unique values in each column.
for i in application_df.columns:
    print(i, len(application_df[i].unique()))
# Out:
# APPLICATION_TYPE 17
# AFFILIATION 6
# CLASSIFICATION 71
# USE_CASE 5
# ORGANIZATION 4
# STATUS 2
# INCOME_AMT 9
# SPECIAL_CONSIDERATIONS 2
# ASK_AMT 8747
# IS_SUCCESSFUL 2

# %%
# Look at APPLICATION_TYPE value counts for binning
apptypecounts = application_df['APPLICATION_TYPE'].value_counts()
apptypecounts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Put the apptypecounts<1000 for this optimization
apptypesreplaced = list(apptypecounts[apptypecounts<1000].index)

# Replace in dataframe
for app in apptypesreplaced:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
binningcounts = application_df['CLASSIFICATION'].value_counts()
binningcounts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classificationcounts = binningcounts[binningcounts>1]
classificationcounts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Put the binningcounts to 1000
classificationsreplaced = list(binningcounts[binningcounts<1000].index)
classificationsreplaced

# Replace in dataframe
for cls in classificationsreplaced:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head(10)
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       1
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
# 5       1     5000              1                       0
# 6       1    31452              1                       0
# 7       1  7508025              1                       0
# 8       1    94389              1                       1
# 9       1     5000              0                       0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns='IS_SUCCESSFUL')
Y = application_df['IS_SUCCESSFUL']


# Split the preprocessed data into a training and testing dataset
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
inputfeatures = X_train_scaled.shape[1]
hiddennodes1 = 80
hiddennodes2 = 30
hiddennodes3 = 1

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units = hiddennodes1, input_dim = inputfeatures, activation='relu'))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units = hiddennodes2, activation='relu'))

# Output layer
nn1.add(tf.keras.layers.Dense(units = hiddennodes3, activation='relu'))

# Check the structure of the model
nn1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3280
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5,741
# Trainable params: 5,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn1.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Train the model
fitmodel = nn1.fit(X_train_scaled, Y_train, validation_split = 0.15, epochs = 100)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.8522 - accuracy: 0.6875 - val_loss: 0.7982 - val_accuracy: 0.7232
# Epoch 2/100
# 684/684 [==============================] - 1s 2ms/step - loss: 0.8265 - accuracy: 0.7014 - val_loss: 1.1193 - val_accuracy: 0.6999
# Epoch 3/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.8641 - accuracy: 0.7050 - val_loss: 0.6636 - val_accuracy: 0.7321
# Epoch 4/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6866 - accuracy: 0.7246 - val_loss: 0.7052 - val_accuracy: 0.7230
# Epoch 5/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6833 - accuracy: 0.7165 - val_loss: 0.6347 - val_accuracy: 0.7175
# Epoch 6/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.6322 - accuracy: 0.7184 - val_loss: 0.6467 - val_accuracy: 0.7318
# Epoch 7/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled, Y_test, verbose = 2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6066 - accuracy: 0.7298 - 281ms/epoch - 1ms/step
# Loss: 0.6066436767578125, Accuracy: 0.7297959327697754

# %%
# Export our model to HDF5 file
nn1.save('../AlphabetSoupCharity_Optimization3.h5')
